# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/mansisinha/taddhita/blob/master/Untitled2.ipynb)

# %%
from google.colab import files
uploaded=files.upload()

import pandas as pd
import io
df=pd.read_csv(io.StringIO(uploaded['allPairs.csv'].decode('utf-8')))
df
# Out:
#      <input type="file" id="files-37219eec-1c40-47d3-8f0a-0ba36cc9736e" name="files[]" multiple disabled />
#      <output id="result-37219eec-1c40-47d3-8f0a-0ba36cc9736e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving allPairs.csv to allPairs (1).csv
#      affix            word    sense  \
# 0       ly       selfishly   manner
# 1       ly      virulently   manner
# 2       ly          gently   manner
# 3       ly    harmoniously   manner
# 4       ly       guardedly   manner
# 5       ly       gushingly   manner
# 6       ly      habitually   manner
# 7       ly         handily   manner
# 8       ly     haphazardly   manner
# 9       ly         happily   manner
# 10      ly       harmfully   manner
# 11      ly      harmlessly   manner
# 12      ly         harshly   manner
# ...

# %%
df.groupby('affix').count()
# Out:
#        word  sense  meaning  Affix  Source Word  Source Word Count  \
# affix
# age      13     13       13     13           13                 13
# al       84     84       84     84           84                 84
# ally    199    199      199    199          199                199
# an       12     12       12     12           12                 12
# ation   109    109      109    109          109                109
# dom      14     14       14     14           14                 14
# ee       70     70       70     70           70                 70
# en       33     33       33     33           33                 33
# er     1425   1425     1425   1425         1425               1425
# ess      18     18       18     18           18                 18
# ette     12     12       12     12           12                 12
# ful      52     52       52     52           52                 52
# hood     39     39       39     39           39                 39
# ...

# %%
from google.colab import files
uploaded=files.upload()

import pandas as pd
import io
df=pd.read_csv(io.StringIO(uploaded['newPairs.csv'].decode('utf-8')))
df
# Out:
#      <input type="file" id="files-663b2f58-0fdd-4bfa-9a27-3c879783ebbc" name="files[]" multiple disabled />
#      <output id="result-663b2f58-0fdd-4bfa-9a27-3c879783ebbc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving newPairs.txt to newPairs.txt
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-c08370fa23b1> in <module>()
#       4 import pandas as pd
#       5 import io
# ----> 6 df=pd.read_csv(io.StringIO(uploaded['newPairs.csv'].decode('utf-8')))
#       7 df
#
# KeyError: 'newPairs.csv'

# %%
# !pip install -q xlrd
# !git clone https://github.com/mansisinha/taddhita.git
# Out:
# Cloning into 'taddhita'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 13 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (13/13), done.

# %%
# !ls taddhita/newPairs.txt
# Out:
# taddhita/newPairs.txt

# %%
import pandas as pd
df2=pd.read_csv('taddhita/newPairs.txt',header=None)
df2
# Out:
#                 0               1      2
# 0            Free         Freeman    man
# 1            Free         Freedom    dom
# 2              of            ofor     or
# 3              of            ofer     er
# 4              of            ofan     an
# 5             the           theic     ic
# 6             the          theism    ism
# 7             the         thester   ster
# 8             the          theist    ist
# 9             the            theo      o
# 10            the           theer     er
# 11            the          thedom    dom
# 12            the           theie     ie
# 13            the            they      y
# 14            the          theion    ion
# 15             is          isness   ness
# 16             is             iso      o
# 17             is            isle     le
# 18             is            iser     er
# 19             is         isation  ation
# 20             is            isen     en
# 21             is           islet    let
# ...

# %%
df2.groupby(2).count()
# Out:
#           0     1
# 2
# affix     3     3
# age     214   214
# al      377   377
# ally    123   123
# an      649   648
# ation   118   118
# dom     118   118
# ee      206   206
# en      996   996
# er     1289  1289
# ess     106   106
# ette    123   123
# ful     225   225
# hood    163   163
# ian     189   189
# ic      206   206
# ical     46    46
# ie      384   384
# ion     149   149
# ise     237   237
# ish     361   361
# ism     276   276
# ist     287   287
# ity     132   132
# ive      94    94
# ize     247   247
# le      276   276
# less    829   829
# let     203   203
# like    746   746
# ling    290   290
# ly      730   730
# man     334   334
# ment    192   192
# ness    672   672
# o      1047  1047
# oid      86    86
# or      366   366
# ous     119   119
# proof    94    94
# ship    125   125
# ster    142   142
# wise    129   129
# y       787   787
